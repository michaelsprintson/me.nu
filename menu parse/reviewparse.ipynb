# %%
import pandas as pd 
import time as t
from lxml import html  
import requests
import json
import numpy as np
from timeit import default_timer as timer
from itertools import cycle
reviews_df=pd.DataFrame()
  
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.0 Safari/605.1.15'
webpage = 'https://www.yelp.com/biz/mala-sichuan-bistro-houston-3'
nextpage = 'something'
xpath_reviews = '//script[@type="application/ld+json"]/text()'
xpath_nextpage = '//link[@rel="next"]'
headers = {'User-Agent': user_agent}

# %%
reviewdf = pd.DataFrame()

while len(nextpage) > 0:
    print('1')
    page = requests.get(webpage, headers = headers)#,proxies={"http": proxy, "https": proxy})
    print('2')
    parser = html.fromstring(page.content)
    reviews = parser.xpath(xpath_reviews)
    nextpage = parser.xpath(xpath_nextpage)
    
    if len(nextpage) > 0:
        nextlink = nextpage[0].get('href')
        print(nextlink, end = '\r')
        webpage = nextlink
        y = json.loads(list(reviews)[0])['review']

        reviewdict = {y.index(i):i for i in y}

        reviewdf = pd.concat([reviewdf,pd.DataFrame(reviewdict).T])
# Out:
# 1
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=20
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=40
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=60
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=80
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=100
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=120
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=140
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=160
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=180
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=200
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=220
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=240
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=260
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=280
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=300
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=320
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=340
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=360
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=380
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=400
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=420
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=440
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=460
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=480
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=500
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=520
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=540
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=560
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=580
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=600
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=620
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=640
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=660
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=680
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=700
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=720
# 2
# 1ttps://www.yelp.com/biz/mala-sichuan-bistro-houston-3?start=740
# 2

# %%
reviewdf
# Out:
#           author datePublished  \
# 0    Brittney T.    2019-07-30
# 1      Andrew L.    2019-09-04
# 2     Rodolfo O.    2019-08-16
# 3       Jando S.    2019-08-09
# 4       Willy N.    2019-07-17
# 5         Sam C.    2019-07-12
# 6     Thierry T.    2019-07-11
# 7        Paul L.    2019-07-11
# 8        Andy C.    2019-06-06
# 9      Jasmin G.    2019-07-28
# 10      Joiya A.    2019-04-25
# 11    Natasha N.    2019-06-20
# 12      Scott L.    2019-02-08
# 13      Colin K.    2019-02-04
# 14     Sandra L.    2019-07-05
# 15     Jibran K.    2019-08-19
# 16     Winnie G.    2019-03-10
# 17        Ted U.    2018-12-30
# 18    Marjona A.    2019-06-14
# 19    Michael K.    2019-01-27
# 0       Quyen N.    2019-07-20
# 1      Rachel B.    2019-05-03
# 2        Lynn N.    2018-10-03
# 3       Maria A.    2019-08-09
# 4   Stephanie T.    2018-09-19
# 5      Calvin C.    2019-07-20
# 6       Leila G.    2018-10-01
# 7        Lucy T.    2019-07-02
# 8        Lana S.    2019-05-05
# 9      Shafiq W.    2019-07-13
# ..           ...           ...
# 10    Jillian W.    2015-03-16
# 11      Maria S.    2013-10-13
# 12         Yi M.    2013-09-22
# 13      Jenny L.    2013-03-16
# 14     Andrea S.    2013-01-14
# 15      Slick V.    2013-11-17
# 16     Sandra A.    2015-02-20
# 17  Catherine L.    2013-02-04
# 18       Sean C.    2015-01-19
# 19     Garden V.    2012-11-24
# 0       Aaaan K.    2014-09-19
# 1        Mrs. D.    2014-11-13
# 2        Alex S.    2014-07-08
# 3         Gan L.    2012-05-13
# 4        Joel B.    2013-07-16
# 5       Chria G.    2014-07-22
# 6      Juliet L.    2014-03-17
# 7        Rina C.    2011-12-17
# 8        Lyla R.    2013-03-03
# 9   Catherine P.    2013-10-19
# 10     travis l.    2013-08-02
# 11      Kevin S.    2014-02-24
# 12      Danni K.    2014-03-16
# 13     Stella S.    2014-03-14
# 14      Susie F.    2015-08-31
# 15       Evan H.    2013-02-09
# 16         JJ T.    2013-11-30
# 17      Maria J.    2013-04-28
# 18        Lee N.    2013-07-11
# 19      James E.    2012-12-02
#
#                                           description        reviewRating
# 0   Amazing food and service. This place has been ...  {'ratingValue': 5}
# 1   Came here for an early dinner on a Wednesday n...  {'ratingValue': 4}
# 2   This place has good dishes. But did not like t...  {'ratingValue': 4}
# 3   Mala Sichuan Bistro likens itself to be a mode...  {'ratingValue': 4}
# 4   I can't believe I've never written a review fo...  {'ratingValue': 5}
# 5   Of all the Szechuan places I've tried in Houst...  {'ratingValue': 4}
# 6   1. Service - friendly waitstaff and cashiers. ...  {'ratingValue': 4}
# 7   If you're a fan of spicy food, you're a fan of...  {'ratingValue': 4}
# 8   Food was decent. Nothing absolutely blew me aw...  {'ratingValue': 4}
# 9   Tried this place for the first time yesterday ...  {'ratingValue': 4}
# 10  Went here with a coworker, his wife, and their...  {'ratingValue': 5}
# 11  Yum! Had a craving for Sichuan food and came h...  {'ratingValue': 4}
# 12  Food was A-OK. Not as hot spicy as expected, w...  {'ratingValue': 3}
# 13  TLDR: This is as authentic as it gets in regar...  {'ratingValue': 4}
# 14  Delicious food and great service. The ants on ...  {'ratingValue': 5}
# 15  I came here 4 times with a different set of fa...  {'ratingValue': 5}
# 16  Was greeted right away and sat down. Ordered 3...  {'ratingValue': 5}
# 17  Mala was exactly what I needed for a nice dinn...  {'ratingValue': 4}
# 18  SPICY food is LIFE!!! I love love spicy food, ...  {'ratingValue': 5}
# 19  Despite perhaps being the most often recommend...  {'ratingValue': 4}
# 0   I kinda hesitated before making a reservation ...  {'ratingValue': 4}
# 1   One of the best Sichuan food in Chinatown. The...  {'ratingValue': 5}
# 2   I have been to Mala several times and I'm alwa...  {'ratingValue': 4}
# 3   My ultimate FAV place to eat Sichuan food!! Th...  {'ratingValue': 5}
# 4   Sichuan food is becoming one of my favorite As...  {'ratingValue': 5}
# 5   If your looking for some good spicy Mala food ...  {'ratingValue': 5}
# 6   The food tastes great but not as spicy as I ex...  {'ratingValue': 4}
# 7   The food here is so so good! My group ordered ...  {'ratingValue': 4}
# 8   Five stars if you're not into spicy food, four...  {'ratingValue': 5}
# 9   Best in town. Prefer the Bellaire location to ...  {'ratingValue': 5}
# ..                                                ...                 ...
# 10  Everything was way way salty. Kind of took ove...  {'ratingValue': 2}
# 11  The worst Chinese food and service. The place ...  {'ratingValue': 1}
# 12  This restaurant try to make more money by not ...  {'ratingValue': 1}
# 13  Most dishes are yummy. \n\nMy favorites are th...  {'ratingValue': 4}
# 14  Very spicy. Very good.  Cumin  beef was well s...  {'ratingValue': 4}
# 15  Maybe it's just me but I wasn't super impresse...  {'ratingValue': 2}
# 16  I love this place!!! My co-workers and I go th...  {'ratingValue': 5}
# 17  Some of the best Chinese food I've ever had! A...  {'ratingValue': 5}
# 18  There are many Chinese restaurants in the same...  {'ratingValue': 1}
# 19  Fantastic food. Spicy or not, well-prepared wi...  {'ratingValue': 5}
# 0   I thought this place would be top notch especi...  {'ratingValue': 2}
# 1   I do not like spicy food and was prepared to j...  {'ratingValue': 5}
# 2   The best sichuan food I've ever had!  Every di...  {'ratingValue': 5}
# 3   The melon and meatball soup was so refreshing ...  {'ratingValue': 4}
# 4   I have lived in the SF Bay and Chicago, both a...  {'ratingValue': 5}
# 5   Spicy crispy chicken is worth the trip alone. ...  {'ratingValue': 4}
# 6   I love this restaurant. I've eaten here over 1...  {'ratingValue': 5}
# 7   four stars solely for the 3 cup chicken.\n\nit...  {'ratingValue': 4}
# 8   My husband and I wanted to try this place out ...  {'ratingValue': 1}
# 9   I thought this place was just okay. It was cra...  {'ratingValue': 3}
# 10  I nerd to preface this review with the fact th...  {'ratingValue': 3}
# 11  Been going here for about a year.  It has gone...  {'ratingValue': 2}
# 12  My coworkers and I enjoy going to this place a...  {'ratingValue': 4}
# 13  Awesome!  Loved the food.  Agreed getting ther...  {'ratingValue': 4}
# 14  The food at Mala Sichuan, when it is on point,...  {'ratingValue': 3}
# 15  Best restaurant in Houston, or at least in the...  {'ratingValue': 5}
# 16  If you want a taste of real Sichuan food, this...  {'ratingValue': 4}
# 17  This is a Chinatown must! Went for dinner last...  {'ratingValue': 4}
# 18  Crazy good! We make the drive from Katy regula...  {'ratingValue': 5}
# 19  previous reviews pretty much cover it all. alm...  {'ratingValue': 4}
#
# [740 rows x 4 columns]

# %%
import copy
df = copy.deepcopy(reviewdf)

# %%
reviewdf = reviewdf.reset_index().drop(['index'],axis=1)

# %%
reviewdf['reviewRating'] = reviewdf['reviewRating'].apply(lambda x:x['ratingValue'])

# %%
menitems = ['pot']

# %%
search = lambda x: [menitem for menitem in menitems if menitem in x]

# %%
reviewdf['containedMenuItems'] = reviewdf['description'].apply(search)

# %%
reviewdf[reviewdf['containedMenuItems'].map(lambda d: len(d) > 0)]
# Out:
#             author datePublished  \
# 3         Jando S.    2019-08-09
# 11      Natasha N.    2019-06-20
# 29       Shafiq W.    2019-07-13
# 32      Jessica R.    2019-07-09
# 33         Lynn H.    2019-03-20
# 42       Isabel W.    2018-10-24
# 46          Fox E.    2018-02-14
# 48       Martha D.    2018-11-18
# 57         Nina J.    2019-07-13
# 74        Laura B.    2017-12-04
# 76       Unaiza P.    2017-12-10
# 77    Stephanie Y.    2018-05-06
# 79        Vegan T.    2018-04-06
# 88       Farhan M.    2019-03-17
# 90        Emily M.    2018-01-01
# 101        Eric C.    2017-01-29
# 104      Warren C.    2017-02-24
# 109    Jinhyung K.    2017-12-24
# 113        Zain A.    2018-07-12
# 122       Lynus J.    2018-08-12
# 129   Christina O.    2018-03-19
# 133       Nancy D.    2017-08-01
# 162     Queenie D.    2017-03-17
# 168       Wendy T.    2015-11-16
# 174        Alan S.    2019-03-17
# 186       Jenny Y.    2018-01-06
# 190         Dan K.    2016-08-25
# 199    Surender B.    2018-07-12
# 200      Jordan Y.    2018-05-29
# 203  Jacqueline Y.    2016-09-03
# ..             ...           ...
# 461       Julia S.    2012-01-30
# 464       Renia L.    2014-07-15
# 471          Yu H.    2012-02-05
# 481        Kari O.    2014-02-28
# 486       Bhanu G.    2015-02-19
# 487       Noble K.    2015-01-04
# 492        King T.    2013-12-18
# 493         Yue D.    2015-01-18
# 516         Dea A.    2013-07-10
# 518      Shelia R.    2016-01-02
# 523       Wendy L.    2013-08-12
# 525         Jin C.    2013-07-28
# 539       linda x.    2017-03-28
# 549   Aishwarya J.    2016-03-07
# 550      Andrew G.    2012-12-25
# 551     Michael S.    2013-08-10
# 562         Tom N.    2013-02-05
# 570        Nick X.    2013-02-13
# 572     Michael L.    2013-01-23
# 574        Lori B.    2015-10-16
# 580        Will W.    2013-01-08
# 588      Howard C.    2014-03-30
# 599     Jeffrey C.    2012-02-03
# 601     Anthony C.    2013-01-27
# 639           T N.    2012-06-23
# 640        Alex S.    2014-09-04
# 656      vitter r.    2014-05-17
# 666        Erin C.    2014-02-04
# 703        Dave S.    2012-07-04
# 724        Joel B.    2013-07-16
#
#                                            description  reviewRating  \
# 3    Mala Sichuan Bistro likens itself to be a mode...             4
# 11   Yum! Had a craving for Sichuan food and came h...             4
# 29   Best in town. Prefer the Bellaire location to ...             5
# 32   If you have not tried this restaurant, you are...             5
# 33   I came back and I loved it! My sister and I go...             5
# 42   I love everything spicy, and since moving here...             4
# 46   If you're suffering from MALAnutrition, and fe...             5
# 48   Okay. This place is the spot for some hype sze...             5
# 57   It's hard to find good quality, authentic Chin...             5
# 74   I'm not even going to pretend to be an expert ...             5
# 76   Mala Sichuan is a family favourite in my house...             4
# 77   I LOVE Sichuan food and have been to a million...             5
# 79   As a vegan, I been on a search for restaurant ...             5
# 88   Mala has great ambience! I went here with two ...             4
# 90   The hype is real! The parking lot can be diffi...             5
# 101  In this week's episode of "The Quest for the B...             5
# 104  Hi there. This is a great spot for some authen...             4
# 109  Solid Sichuan food. No complaints about this p...             4
# 113  Make no mistake potential new patrons -- this ...             1
# 122  Fast service and great tasting food! We liked ...             4
# 129  I picked this spot because it was new and we l...             4
# 133  Mala is one of the best restaurants for Szechu...             4
# 162  Their food is all great if you like spicy food...             5
# 168  I just love eating here when I need to get my ...             5
# 174  We tried the Mongolian beef and the black pepp...             4
# 186  I was in town for a few days to visit my dad (...             4
# 190  My mouth might still be pleasantly numb from t...             4
# 199  Rice is the Central Item of a Chinese meal - a...             1
# 200  Best Sichuan spot in Houston. Spicy salty savo...             5
# 203  Our first day back in Houston and all I wanted...             4
# ..                                                 ...           ...
# 461  Ugh, now why did I do that? I stuffed myself s...             4
# 464  Located in the heart of Chinatown on Bellaire ...             4
# 471  This has quickly become my favorite Chinese re...             5
# 481  Getting here and parking here is probably the ...             4
# 486  Never disappoints... We always come here whene...             5
# 487  This has been on my "list of places for try" f...             4
# 492  First off...parking in this strip mall is TERR...             3
# 493  Can't believe I haven't reviewed this place! I...             4
# 516  The spicy eggplant. This dish. I love eggplant...             4
# 518  Great SICHUAN restaurant! Spicy crispy chicken...             5
# 523  This place is your typical Chinatown restauran...             4
# 525  Went here Saturday and enjoyed an excellent, s...             4
# 539  3.5? Take in mind I'm probably more critical o...             3
# 549  Everything I tried was soo good! If I were to ...             5
# 550  Before I get to my review of the horrendous an...             1
# 551  We've been branching out lately from our usual...             3
# 562  After reading through all 71 reviews, I'm surp...             4
# 570  Maybe loving spicy food is why I rate all the ...             5
# 572  Definitely have some Ma-la action here.  This ...             4
# 574  Ordered the red oil Winton's and they were ama...             4
# 580  went there for lunch on a tuesday around noon....             2
# 588  I'm frequently in Chinatown and Mala Sichuan h...             4
# 599  As a Taiwanese-American (on my father's side),...             5
# 601  Sichuan in Houston? this is it!!! NYTimes them...             5
# 639  I love spicy food and this place hit the spot!...             4
# 640  A simple restaurant with sometimes spotty serv...             5
# 656  Nice atmosphere compared to some places in thi...             5
# 666  This is definitely the best spicy Chinese food...             4
# 703  Our group of five adults went for an early din...             5
# 724  I have lived in the SF Bay and Chicago, both a...             5
#
#     containedMenuItems
# 3                [pot]
# 11               [pot]
# 29               [pot]
# 32               [pot]
# 33               [pot]
# 42               [pot]
# 46               [pot]
# 48               [pot]
# 57               [pot]
# 74               [pot]
# 76               [pot]
# 77               [pot]
# 79               [pot]
# 88               [pot]
# 90               [pot]
# 101              [pot]
# 104              [pot]
# 109              [pot]
# 113              [pot]
# 122              [pot]
# 129              [pot]
# 133              [pot]
# 162              [pot]
# 168              [pot]
# 174              [pot]
# 186              [pot]
# 190              [pot]
# 199              [pot]
# 200              [pot]
# 203              [pot]
# ..                 ...
# 461              [pot]
# 464              [pot]
# 471              [pot]
# 481              [pot]
# 486              [pot]
# 487              [pot]
# 492              [pot]
# 493              [pot]
# 516              [pot]
# 518              [pot]
# 523              [pot]
# 525              [pot]
# 539              [pot]
# 549              [pot]
# 550              [pot]
# 551              [pot]
# 562              [pot]
# 570              [pot]
# 572              [pot]
# 574              [pot]
# 580              [pot]
# 588              [pot]
# 599              [pot]
# 601              [pot]
# 639              [pot]
# 640              [pot]
# 656              [pot]
# 666              [pot]
# 703              [pot]
# 724              [pot]
#
# [87 rows x 5 columns]

# %%
reviewdf.iloc[412]['description']
# Out:
# "If I could give Mala more stars, I would.  Our meal here was absolutely amazing and I am already making plans to go back whenever I return to Houston!\n\nWe came on a busy night but did not have to wait too long to grab a table (with a lazy susan no less!!).  We ordered the red oil dumplings, the red oil rabbit, the dan dan noodles, the mapo tofu, the three pepper beaten duck, the chengdu style pot roasted prawns, and the mala crispy beef.  Oh. My. Goodness.  Everything was amazing!! The dan dan noodles were nice and chewy and full of spicy flavor.  The wrapping on the dumplings were chewy and had such a great mouth feel.  The mapo tofu sauce was thick and spicy and went perfectly with our steaming hot rice.  The duck was tender and crispy and moist.  The prawns were juicy and absorbed all that rich flavor - not to mention they were a good size! The mala crispy beef was a show stopper - thinly sliced spicy crispy morsels... delicious!  I didn't enjoy the rabbit as much as I thought I would because there were so many bones amongst the meat, but the meat tasted great. \n\nThe service there was great - our waiter was very nice and made sure we had everything we needed.  Overall, it was a very enjoyable feeling and we devoured almost every last bite!  I recommend this place with very high regard - I cannot wait to come back!"

# %%
reviewdf.to_json('bigmala')
