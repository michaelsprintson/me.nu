# %%
import pandas as pd 
import time as t
from lxml import html  
import requests
import json
from timeit import default_timer as timer
reviews_df=pd.DataFrame()
  
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.0 Safari/605.1.15'
webpage = 'https://www.yelp.com/biz/mala-sichuan-bistro-houston-4'
nextpage = 'something'
xpath_reviews = '//script[@type="application/ld+json"]/text()'
xpath_nextpage = '//link[@rel="next"]'
headers = {'User-Agent': user_agent}

# %%
reviewdf = pd.DataFrame()
while len(nextpage) > 0:
    page = requests.get(webpage, headers = headers)

    parser = html.fromstring(page.content)
    reviews = parser.xpath(xpath_reviews)
    nextpage = parser.xpath(xpath_nextpage)
    
    if len(nextpage) > 0:
        nextlink = nextpage[0].get('href')
        print(nextlink, end = '\r')
        webpage = nextlink
        y = json.loads(list(reviews)[0])['review']

        reviewdict = {y.index(i):i for i in y}

        reviewdf = pd.concat([reviewdf,pd.DataFrame(reviewdict).T])
# Out:
# https://www.yelp.com/biz/mala-sichuan-bistro-houston-4?start=420

# %%
reviewdf = reviewdf.reset_index().drop(['index'],axis=1)

# %%
reviewdf
# Out:
#             author datePublished  \
# 0        Martha D.    2019-09-20
# 1        Bianca C.    2019-09-12
# 2        Philip S.    2019-09-03
# 3        Jeremy K.    2019-08-17
# 4        Daniel L.    2019-03-02
# 5          Zain R.    2019-01-16
# 6         Faris K.    2019-08-30
# 7      Jennifer Y.    2018-12-28
# 8        Lauren R.    2019-08-24
# 9        Lauren B.    2019-02-24
# 10           HC W.    2019-08-14
# 11         Tony N.    2019-09-09
# 12         Akin B.    2019-04-22
# 13       Moriah H.    2019-04-23
# 14    Catherine L.    2019-01-25
# 15      Areesha A.    2018-12-17
# 16          Dan P.    2019-07-25
# 17     Brittany G.    2019-09-02
# 18       Jacqui L.    2018-09-14
# 19         John W.    2019-06-21
# 20        Vicky L.    2018-06-03
# 21   Soumyadeep G.    2019-07-08
# 22      William D.    2019-03-20
# 23        Megan T.    2019-02-06
# 24       Jackie M.    2018-06-05
# 25         Piya K.    2019-06-01
# 26       Reagan O.    2019-04-22
# 27       Gordon K.    2018-11-11
# 28          Leo D.    2019-01-02
# 29        Jinny M.    2019-08-12
# ..             ...           ...
# 390         Joe Z.    2015-09-20
# 391        Xuan L.    2015-09-18
# 392     Matthew M.    2016-08-13
# 393        Eric A.    2015-05-30
# 394         Ced B.    2015-08-25
# 395           J H.    2016-10-13
# 396        Hana L.    2015-08-05
# 397           C P.    2016-10-23
# 398         Ida G.    2015-07-06
# 399           T F.    2016-09-13
# 400      Miriam J.    2015-06-20
# 401         Jay L.    2016-07-27
# 402        Kgee G.    2015-06-01
# 403     Gormand M.    2015-05-15
# 404        John W.    2015-08-16
# 405     Douglas M.    2016-06-17
# 406       Peter Y.    2015-11-03
# 407           J W.    2015-08-10
# 408       David A.    2015-08-07
# 409       Casey C.    2015-08-07
# 410       Kelly S.    2016-04-01
# 411          Mr C.    2015-10-08
# 412          W. G.    2016-01-01
# 413    Jennifer C.    2016-03-26
# 414           R B.    2015-08-10
# 415       Emily B.    2015-05-14
# 416       Maria S.    2015-11-14
# 417        Faye P.    2015-06-02
# 418         Tim W.    2015-10-09
# 419        abby r.    2015-08-13
#
#                                            description        reviewRating
# 0    Always a favorite for Sichuan food. This place...  {'ratingValue': 5}
# 1    I came here with my good friend to grab dinner...  {'ratingValue': 5}
# 2    Best Sichuan place in Houston, beware some of ...  {'ratingValue': 5}
# 3    Mala Sichuan is delicious, which is why they w...  {'ratingValue': 5}
# 4    My dining companions and I teed up a variety o...  {'ratingValue': 4}
# 5    Deciding upon a dining place can be difficult ...  {'ratingValue': 4}
# 6    Go here and get the eggplant. You will be very...  {'ratingValue': 5}
# 7    Parking is typically valet only but I came on ...  {'ratingValue': 3}
# 8    I come here frequently for dinner, but during ...  {'ratingValue': 4}
# 9    Umm I have no idea why this place doesn't have...  {'ratingValue': 5}
# 10   Tried this place again and it was better secon...  {'ratingValue': 4}
# 11   We dine here frequently. One of the best Sichu...  {'ratingValue': 5}
# 12   Pretty good Sichuan restaurant! The service wa...  {'ratingValue': 3}
# 13   Okay I actually hated this place. I am rating ...  {'ratingValue': 5}
# 14   SO SO GOOOOD! My girl is a pro (ok, she's pret...  {'ratingValue': 4}
# 15   ummm YUMM!!!! This place has been recommended ...  {'ratingValue': 4}
# 16   Summary: Incredible Sichuan cuisine in a vibra...  {'ratingValue': 5}
# 17   The days and hours are kinda weird, so I've de...  {'ratingValue': 5}
# 18   Good place in the area (and not in Chinatown) ...  {'ratingValue': 4}
# 19   I don't know why I like this place so much.  I...  {'ratingValue': 4}
# 20   Came with a hungry group of four because we we...  {'ratingValue': 2}
# 21   This place has never disappointed me. You cann...  {'ratingValue': 5}
# 22   Absolute waste of money! Had to throw out 2 en...  {'ratingValue': 1}
# 23   Very good Chinese food. My Chinese coworker to...  {'ratingValue': 4}
# 24   I used to REALLY like this place, but lately I...  {'ratingValue': 2}
# 25   Mala Sichuan is my no.1 pick for Sichuan resta...  {'ratingValue': 5}
# 26   I had a great time with my friends at this est...  {'ratingValue': 5}
# 27   My Ma Po tofu did not have the excess salt lik...  {'ratingValue': 4}
# 28   Lines are long and the restaurant was not taki...  {'ratingValue': 2}
# 29   The food was decent but overpriced. They do no...  {'ratingValue': 2}
# ..                                                 ...                 ...
# 390  The food was excellent but 8 bucks for a tiny ...  {'ratingValue': 3}
# 391  So spicy and so good!! Not as child friendly a...  {'ratingValue': 5}
# 392  This place is excellent.   Suggest ordering re...  {'ratingValue': 5}
# 393  Came again.  Was much happier this time.  Didn...  {'ratingValue': 4}
# 394  So dope. We got the dan dan noodles, cucumber ...  {'ratingValue': 5}
# 395  Food was excellent, atmosphere, modern and fun...  {'ratingValue': 4}
# 396  We had the first one on the menu (it was somet...  {'ratingValue': 4}
# 397  Are here recently. Parking can be a challenge ...  {'ratingValue': 4}
# 398  Oooh!!!  So good!\n\nWe love spicy food so thi...  {'ratingValue': 5}
# 399  We went there on a Friday night so the restaur...  {'ratingValue': 3}
# 400  Best and most authentic Chinese food we've had...  {'ratingValue': 5}
# 401  Delicious Sichuan you can't find anywhere else...  {'ratingValue': 5}
# 402  Wow! Best Chinese food I've had in a while. \n...  {'ratingValue': 5}
# 403  I never imagined mala will open a branch in mo...  {'ratingValue': 5}
# 404  I loved this place, and I will definitely be b...  {'ratingValue': 5}
# 405  The pork was a bit tough, and the flavors blan...  {'ratingValue': 2}
# 406  This place is great! It can be slightly on the...  {'ratingValue': 5}
# 407  WARNING: Worst dining experience ever.  Sent o...  {'ratingValue': 1}
# 408  The music is too loud and the food is too oily...  {'ratingValue': 1}
# 409  If this is authentic Chinese food I do not wan...  {'ratingValue': 2}
# 410  I really love this place! The food was amazing...  {'ratingValue': 5}
# 411  I've been here at least 6 times now and overal...  {'ratingValue': 4}
# 412  Being a fan of Sichuan, I had a little doubt a...  {'ratingValue': 5}
# 413  Best Szechuan ever.  I eat here regularly and ...  {'ratingValue': 5}
# 414  Really bad customer service from Cori (who she...  {'ratingValue': 1}
# 415  As a huge fan of the Bellaire location, when I...  {'ratingValue': 5}
# 416  The place is a bit dirty. The food is so greas...  {'ratingValue': 1}
# 417  I was so excited to hear that Mala Sichuan was...  {'ratingValue': 5}
# 418  If you're looking for a flavor bomb, this auth...  {'ratingValue': 5}
# 419  The food was really good but really really spi...  {'ratingValue': 4}
#
# [420 rows x 4 columns]

# %%
reviewdf['reviewRating'] = reviewdf['reviewRating'].apply(lambda x:x['ratingValue'])

# %%
reviewdf
# Out:
#             author datePublished  \
# 0        Martha D.    2019-09-20
# 1        Bianca C.    2019-09-12
# 2        Philip S.    2019-09-03
# 3        Jeremy K.    2019-08-17
# 4        Daniel L.    2019-03-02
# 5          Zain R.    2019-01-16
# 6         Faris K.    2019-08-30
# 7      Jennifer Y.    2018-12-28
# 8        Lauren R.    2019-08-24
# 9        Lauren B.    2019-02-24
# 10           HC W.    2019-08-14
# 11         Tony N.    2019-09-09
# 12         Akin B.    2019-04-22
# 13       Moriah H.    2019-04-23
# 14    Catherine L.    2019-01-25
# 15      Areesha A.    2018-12-17
# 16          Dan P.    2019-07-25
# 17     Brittany G.    2019-09-02
# 18       Jacqui L.    2018-09-14
# 19         John W.    2019-06-21
# 20        Vicky L.    2018-06-03
# 21   Soumyadeep G.    2019-07-08
# 22      William D.    2019-03-20
# 23        Megan T.    2019-02-06
# 24       Jackie M.    2018-06-05
# 25         Piya K.    2019-06-01
# 26       Reagan O.    2019-04-22
# 27       Gordon K.    2018-11-11
# 28          Leo D.    2019-01-02
# 29        Jinny M.    2019-08-12
# ..             ...           ...
# 390         Joe Z.    2015-09-20
# 391        Xuan L.    2015-09-18
# 392     Matthew M.    2016-08-13
# 393        Eric A.    2015-05-30
# 394         Ced B.    2015-08-25
# 395           J H.    2016-10-13
# 396        Hana L.    2015-08-05
# 397           C P.    2016-10-23
# 398         Ida G.    2015-07-06
# 399           T F.    2016-09-13
# 400      Miriam J.    2015-06-20
# 401         Jay L.    2016-07-27
# 402        Kgee G.    2015-06-01
# 403     Gormand M.    2015-05-15
# 404        John W.    2015-08-16
# 405     Douglas M.    2016-06-17
# 406       Peter Y.    2015-11-03
# 407           J W.    2015-08-10
# 408       David A.    2015-08-07
# 409       Casey C.    2015-08-07
# 410       Kelly S.    2016-04-01
# 411          Mr C.    2015-10-08
# 412          W. G.    2016-01-01
# 413    Jennifer C.    2016-03-26
# 414           R B.    2015-08-10
# 415       Emily B.    2015-05-14
# 416       Maria S.    2015-11-14
# 417        Faye P.    2015-06-02
# 418         Tim W.    2015-10-09
# 419        abby r.    2015-08-13
#
#                                            description  reviewRating
# 0    Always a favorite for Sichuan food. This place...             5
# 1    I came here with my good friend to grab dinner...             5
# 2    Best Sichuan place in Houston, beware some of ...             5
# 3    Mala Sichuan is delicious, which is why they w...             5
# 4    My dining companions and I teed up a variety o...             4
# 5    Deciding upon a dining place can be difficult ...             4
# 6    Go here and get the eggplant. You will be very...             5
# 7    Parking is typically valet only but I came on ...             3
# 8    I come here frequently for dinner, but during ...             4
# 9    Umm I have no idea why this place doesn't have...             5
# 10   Tried this place again and it was better secon...             4
# 11   We dine here frequently. One of the best Sichu...             5
# 12   Pretty good Sichuan restaurant! The service wa...             3
# 13   Okay I actually hated this place. I am rating ...             5
# 14   SO SO GOOOOD! My girl is a pro (ok, she's pret...             4
# 15   ummm YUMM!!!! This place has been recommended ...             4
# 16   Summary: Incredible Sichuan cuisine in a vibra...             5
# 17   The days and hours are kinda weird, so I've de...             5
# 18   Good place in the area (and not in Chinatown) ...             4
# 19   I don't know why I like this place so much.  I...             4
# 20   Came with a hungry group of four because we we...             2
# 21   This place has never disappointed me. You cann...             5
# 22   Absolute waste of money! Had to throw out 2 en...             1
# 23   Very good Chinese food. My Chinese coworker to...             4
# 24   I used to REALLY like this place, but lately I...             2
# 25   Mala Sichuan is my no.1 pick for Sichuan resta...             5
# 26   I had a great time with my friends at this est...             5
# 27   My Ma Po tofu did not have the excess salt lik...             4
# 28   Lines are long and the restaurant was not taki...             2
# 29   The food was decent but overpriced. They do no...             2
# ..                                                 ...           ...
# 390  The food was excellent but 8 bucks for a tiny ...             3
# 391  So spicy and so good!! Not as child friendly a...             5
# 392  This place is excellent.   Suggest ordering re...             5
# 393  Came again.  Was much happier this time.  Didn...             4
# 394  So dope. We got the dan dan noodles, cucumber ...             5
# 395  Food was excellent, atmosphere, modern and fun...             4
# 396  We had the first one on the menu (it was somet...             4
# 397  Are here recently. Parking can be a challenge ...             4
# 398  Oooh!!!  So good!\n\nWe love spicy food so thi...             5
# 399  We went there on a Friday night so the restaur...             3
# 400  Best and most authentic Chinese food we've had...             5
# 401  Delicious Sichuan you can't find anywhere else...             5
# 402  Wow! Best Chinese food I've had in a while. \n...             5
# 403  I never imagined mala will open a branch in mo...             5
# 404  I loved this place, and I will definitely be b...             5
# 405  The pork was a bit tough, and the flavors blan...             2
# 406  This place is great! It can be slightly on the...             5
# 407  WARNING: Worst dining experience ever.  Sent o...             1
# 408  The music is too loud and the food is too oily...             1
# 409  If this is authentic Chinese food I do not wan...             2
# 410  I really love this place! The food was amazing...             5
# 411  I've been here at least 6 times now and overal...             4
# 412  Being a fan of Sichuan, I had a little doubt a...             5
# 413  Best Szechuan ever.  I eat here regularly and ...             5
# 414  Really bad customer service from Cori (who she...             1
# 415  As a huge fan of the Bellaire location, when I...             5
# 416  The place is a bit dirty. The food is so greas...             1
# 417  I was so excited to hear that Mala Sichuan was...             5
# 418  If you're looking for a flavor bomb, this auth...             5
# 419  The food was really good but really really spi...             4
#
# [420 rows x 4 columns]
