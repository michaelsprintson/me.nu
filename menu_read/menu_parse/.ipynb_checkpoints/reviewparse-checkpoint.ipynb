# %%
import pandas as pd 
import time as t
from lxml import html  
import requests
import json
import numpy as np
from timeit import default_timer as timer
from itertools import cycle
import string

# %%
food = True

# %%
if food:
    respage = 'https://www.yelp.com/biz/mala-sichuan-bistro-houston-3'
    switch = 'food'
else:
    respage = 'https://www.yelp.com/biz/sharetea-houston-2'
    switch = 'tea'

# %% [markdown]
# # OCR FUNCTIONALITY TEST

# %%
import sys
sys.path.append('../')

# %%
cd ~/Documents/GitHub/me.nu/menu_read
# Out:
# /Users/michaelsprintson/Documents/GitHub/me.nu/menu_read

# %%
pip install --upgrade google-cloud-vision
# Out:
# Collecting google-cloud-vision
#   Downloading https://files.pythonhosted.org/packages/ec/e3/77b17733592fde11b7250444ddedd8d04ae1be6f0f4c0d9f47ed154a686e/google_cloud_vision-0.39.0-py2.py3-none-any.whl (418kB)
#      |████████████████████████████████| 419kB 7.2MB/s eta 0:00:01
# Collecting google-api-core[grpc]<2.0.0dev,>=1.14.0 (from google-cloud-vision)
#   Downloading https://files.pythonhosted.org/packages/71/e5/7059475b3013a3c75abe35015c5761735ab224eb1b129fee7c8e376e7805/google_api_core-1.14.2-py2.py3-none-any.whl (68kB)
#      |████████████████████████████████| 71kB 17.8MB/s eta 0:00:01
# Collecting googleapis-common-protos<2.0dev,>=1.6.0 (from google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision)
#   Downloading https://files.pythonhosted.org/packages/eb/ee/e59e74ecac678a14d6abefb9054f0bbcb318a6452a30df3776f133886d7d/googleapis-common-protos-1.6.0.tar.gz
# Requirement already satisfied, skipping upgrade: google-auth<2.0dev,>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (1.6.3)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (1.12.0)
# Requirement already satisfied, skipping upgrade: setuptools>=34.0.0 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (41.0.1)
# Requirement already satisfied, skipping upgrade: protobuf>=3.4.0 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (3.9.0)
# Requirement already satisfied, skipping upgrade: pytz in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (2019.1)
# Requirement already satisfied, skipping upgrade: requests<3.0.0dev,>=2.18.0 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (2.22.0)
# Requirement already satisfied, skipping upgrade: grpcio<2.0dev,>=1.8.2; extra == "grpc" in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (1.22.0)
# Requirement already satisfied, skipping upgrade: cachetools>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from google-auth<2.0dev,>=0.4.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (3.1.1)
# Requirement already satisfied, skipping upgrade: rsa>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from google-auth<2.0dev,>=0.4.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (4.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from google-auth<2.0dev,>=0.4.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (0.2.6)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (2.8)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (1.25.5)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (2019.6.16)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from rsa>=3.1.4->google-auth<2.0dev,>=0.4.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-vision) (0.4.7)
# Building wheels for collected packages: googleapis-common-protos
#   Building wheel for googleapis-common-protos (setup.py) ... done
#   Created wheel for googleapis-common-protos: filename=googleapis_common_protos-1.6.0-cp37-none-any.whl size=77578 sha256=61cbd2aeb31e09d2136a937fceec156b31d96d8e7fbd46bc273dcd615d1af9d0
#   Stored in directory: /Users/michaelsprintson/Library/Caches/pip/wheels/9e/3d/a2/1bec8bb7db80ab3216dbc33092bb7ccd0debfb8ba42b5668d5
# Successfully built googleapis-common-protos
# Installing collected packages: googleapis-common-protos, google-api-core, google-cloud-vision
# Successfully installed google-api-core-1.14.2 google-cloud-vision-0.39.0 googleapis-common-protos-1.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import ocr_food

# %%
# create dictionary
d = ocr_food.load_words('ocr\alpha_words.txt')

pic_loc = 'ocr\\menupictures\\othermenu\\othermenu8.jpg'
test_file_name = 'othermenutest8'
detect_text(pic_loc, test_file_name)

print(final_dump("ocr\\menu_tests\\othermenutest7.txt", "menu_read\\pref_sample.txt", True, "othermenutest7"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-646-aad820ec43dd> in <module>
#       1 # create dictionary
# ----> 2 d = ocr_food.load_words('ocr\alpha_words.txt')
#       3
#       4 pic_loc = 'ocr\\menupictures\\othermenu\\othermenu8.jpg'
#       5 test_file_name = 'othermenutest8'
#
# TypeError: load_words() takes 0 positional arguments but 1 was given

# %% [markdown]
# # IMPORT RESTERAUNT REVIEWS

# %% [markdown]
# ## IMPORT YELP REVIEWS

# %%
reviews_df=pd.DataFrame()
  
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.0 Safari/605.1.15'
webpage = ''
nextpage = 'something'
xpath_reviews = '//script[@type="application/ld+json"]/text()'
xpath_nextpage = '//link[@rel="next"]'
headers = {'User-Agent': user_agent}

# %%
reviewdf = pd.DataFrame()

while len(nextpage) > 0:
    #print('1')
    page = requests.get(webpage, headers = headers)#,proxies={"http": proxy, "https": proxy})
    print('pagegot','\r')
    parser = html.fromstring(page.content)
    reviews = parser.xpath(xpath_reviews)
    nextpage = parser.xpath(xpath_nextpage)
    
    if len(nextpage) > 0:
        nextlink = nextpage[0].get('href')
        print(nextlink, end = '\r')
        webpage = nextlink
        y = json.loads(list(reviews)[0])['review']

        reviewdict = {y.index(i):i for i in y}

        reviewdf = pd.concat([reviewdf,pd.DataFrame(reviewdict).T])
# Out:
# pagegot
# pagegot www.yelp.com/biz/sharetea-houston-2?start=20
# pagegot www.yelp.com/biz/sharetea-houston-2?start=40
# pagegot www.yelp.com/biz/sharetea-houston-2?start=60
# pagegot www.yelp.com/biz/sharetea-houston-2?start=80
# pagegot www.yelp.com/biz/sharetea-houston-2?start=100
# pagegot www.yelp.com/biz/sharetea-houston-2?start=120
# pagegot www.yelp.com/biz/sharetea-houston-2?start=140
# pagegot www.yelp.com/biz/sharetea-houston-2?start=160
# pagegot www.yelp.com/biz/sharetea-houston-2?start=180
# pagegot www.yelp.com/biz/sharetea-houston-2?start=200
# pagegot www.yelp.com/biz/sharetea-houston-2?start=220
# pagegot www.yelp.com/biz/sharetea-houston-2?start=240
# pagegot www.yelp.com/biz/sharetea-houston-2?start=260
# pagegot www.yelp.com/biz/sharetea-houston-2?start=280
# pagegot www.yelp.com/biz/sharetea-houston-2?start=300
# pagegot www.yelp.com/biz/sharetea-houston-2?start=320
# pagegot www.yelp.com/biz/sharetea-houston-2?start=340
# pagegot www.yelp.com/biz/sharetea-houston-2?start=360
# pagegot www.yelp.com/biz/sharetea-houston-2?start=380
# pagegot www.yelp.com/biz/sharetea-houston-2?start=400
# pagegot www.yelp.com/biz/sharetea-houston-2?start=420
# pagegot www.yelp.com/biz/sharetea-houston-2?start=440
# pagegot www.yelp.com/biz/sharetea-houston-2?start=460
# pagegot www.yelp.com/biz/sharetea-houston-2?start=480
# pagegot www.yelp.com/biz/sharetea-houston-2?start=500
# pagegot www.yelp.com/biz/sharetea-houston-2?start=520
# pagegot www.yelp.com/biz/sharetea-houston-2?start=540

# %%
reviewdf = reviewdf.reset_index()
reviewdf.drop(['index'],axis=1)
# Out:
#                    author datePublished  \
# 0                  Tom P.    2019-08-10
# 1              Henry V L.    2019-08-20
# 2                Karen T.    2019-08-01
# 3                  Sam K.    2019-09-21
# 4             Jennifer Y.    2019-07-23
# 5                  Tri D.    2019-08-14
# 6                Sasha E.    2019-07-21
# 7                Diane S.    2019-07-21
# 8                Cathy L.    2019-07-11
# 9               Angela A.    2019-04-01
# 10               Joiya A.    2019-03-17
# 11                Zhao C.    2019-09-01
# 12             Brandon K.    2019-09-15
# 13           Annelaure N.    2019-06-08
# 14                Mimi N.    2019-05-21
# 15               Jerry H.    2019-05-30
# 16              Ashley C.    2019-04-03
# 17                Tori S.    2019-04-05
# 18           Stephanie N.    2019-03-29
# 19                 Fox E.    2019-02-27
# 20               Thanh D.    2019-03-07
# 21               Alisa S.    2019-05-03
# 22                Lily S.    2019-03-09
# 23   Yingyao Catherine S.    2018-07-29
# 24                Lily H.    2019-08-28
# 25              Kelley J.    2018-07-24
# 26                 Ozy M.    2019-07-10
# 27                Ying X.    2018-12-08
# 28               Karen L.    2018-07-29
# 29             Cynthia V.    2019-03-21
# ..                    ...           ...
# 510              Jenny H.    2015-09-27
# 511             Freddy D.    2016-06-12
# 512             Truong L.    2015-09-29
# 513               Sean L.    2016-12-07
# 514               Gigi H.    2016-01-15
# 515             Eugene L.    2016-07-14
# 516            Michael C.    2015-10-23
# 517             Victor C.    2015-10-20
# 518              Yanan L.    2015-10-18
# 519             Shirin H.    2016-11-03
# 520             Celine C.    2015-10-16
# 521                P M C.    2016-09-24
# 522               Jane T.    2015-10-16
# 523             Hannie B.    2016-05-16
# 524             Andrew T.    2015-10-03
# 525                  E H.    2016-06-13
# 526              Janet L.    2016-06-04
# 527              Chris S.    2016-06-20
# 528             Vivian L.    2015-10-11
# 529             Joanna H.    2015-09-30
# 530               John T.    2016-07-01
# 531             Nicole W.    2015-12-23
# 532                  S C.    2016-05-30
# 533              Meili L.    2016-01-18
# 534          Christine M.    2016-04-17
# 535              Heidi R.    2015-10-26
# 536             Sharon C.    2015-10-04
# 537              Bryan D.    2016-02-27
# 538            Deborah c.    2016-02-01
# 539            William F.    2016-02-20
#
#                                            description        reviewRating
# 0    Visited Sharetea in Chinatown for the first ti...  {'ratingValue': 5}
# 1    Sharetea?? Nooo thanks cuz boba is my lifeeee....  {'ratingValue': 3}
# 2    Update - August 1, 2019\n\nAs always, Sharetea...  {'ratingValue': 5}
# 3    I've never been to a bubble tea place where yo...  {'ratingValue': 4}
# 4    Typically get the classic milk tea (green) wit...  {'ratingValue': 4}
# 5    Out of all the bubble tea/smoothie places I've...  {'ratingValue': 5}
# 6    Love this ShareTea location because the space ...  {'ratingValue': 3}
# 7    Walked in. They are advertising for the Chai t...  {'ratingValue': 3}
# 8    I love sharetea because it's one of the few pl...  {'ratingValue': 4}
# 9    Sharetea is most likely my top teahouse in Hou...  {'ratingValue': 5}
# 10   I finally made it to Sharetea after having it ...  {'ratingValue': 4}
# 11   My favorite boba tea place in the area! Not on...  {'ratingValue': 5}
# 12   They make the best strawberry green tea with b...  {'ratingValue': 5}
# 13   Sorry I think this place is a taaaad too overr...  {'ratingValue': 2}
# 14   Sharetea is always busy when I go. This is my ...  {'ratingValue': 5}
# 15   Came here late at night and was sad to hear th...  {'ratingValue': 3}
# 16   My first ever Sharetea encounter. Honestly out...  {'ratingValue': 4}
# 17   Goodness, how do I even start with this? \n\nE...  {'ratingValue': 5}
# 18   Mango green tea with 80% sweetness is the way ...  {'ratingValue': 4}
# 19   I'm gonna get fat cuz I always go to SHARETEA\...  {'ratingValue': 5}
# 20   Of all the bubble tea places in Chinatown, thi...  {'ratingValue': 5}
# 21   Great selection. Long line but wait was not ho...  {'ratingValue': 5}
# 22   I love Sharetea! This location is awesome. Alw...  {'ratingValue': 4}
# 23   The environment was so bad as there were sever...  {'ratingValue': 4}
# 24   My fiance loves Sharetea's Bubble Tea so we al...  {'ratingValue': 4}
# 25   Weekdays, this is my favorite milk tea place t...  {'ratingValue': 4}
# 26   Come here all the time. Love this place and wi...  {'ratingValue': 5}
# 27   Pretty comparable to any other Sharetea locati...  {'ratingValue': 4}
# 28   This place is my new work spot. I have been co...  {'ratingValue': 5}
# 29   The menu here is huge! So many choices, so lit...  {'ratingValue': 4}
# ..                                                 ...                 ...
# 510  New place in town! The tea and boba is ok! But...  {'ratingValue': 2}
# 511  I bought the first drink when it started grand...  {'ratingValue': 1}
# 512  We came here during their grand opening, the p...  {'ratingValue': 3}
# 513  The matcha milk tea with red bean is the best ...  {'ratingValue': 5}
# 514  This is the only place I go to for tea these d...  {'ratingValue': 4}
# 515  Best milk tea in town, hands down! I tried sev...  {'ratingValue': 5}
# 516  When I saw the Sharetea logo put up in the pla...  {'ratingValue': 2}
# 517  Tastes good to me. High mountain with fresh mi...  {'ratingValue': 4}
# 518  So excited that they open in Houston. Had thei...  {'ratingValue': 4}
# 519  This place is pretty spacious and seems like a...  {'ratingValue': 3}
# 520  I ordered milk tea with herb jelly, 30%sugar a...  {'ratingValue': 4}
# 521  It was my first time and I tried the Hawaii te...  {'ratingValue': 5}
# 522  I really love the drinks here but Please , cas...  {'ratingValue': 4}
# 523  Has the matcha milk tea with taro 50% sweet. T...  {'ratingValue': 5}
# 524  Long wait but the tea is pretty good. Lines ca...  {'ratingValue': 4}
# 525  I've had a couple drinks here, and I just thin...  {'ratingValue': 3}
# 526  So I told the cashier that I wanted no sugar. ...  {'ratingValue': 1}
# 527  I've had Sharetea once before in California an...  {'ratingValue': 5}
# 528  Overall the drinks here are above-average qual...  {'ratingValue': 3}
# 529  No lines and long wait times my second trip he...  {'ratingValue': 2}
# 530  I've been going to Sharetea almost weekly sinc...  {'ratingValue': 1}
# 531  They really like to let the customers waiting ...  {'ratingValue': 1}
# 532  It takes 30min to get in the door and place an...  {'ratingValue': 3}
# 533  Well to start, Sharetea is a nice contemporary...  {'ratingValue': 1}
# 534  One of the best boba teas! The boba is soft an...  {'ratingValue': 5}
# 535  Their tea is very good. I ended up getting one...  {'ratingValue': 4}
# 536  They were very very generous with tapioca in m...  {'ratingValue': 5}
# 537  As with most tapioca places, it's either great...  {'ratingValue': 4}
# 538  This place has the best milk tea.  Flavorful t...  {'ratingValue': 5}
# 539  This place is just your average teahouse, noth...  {'ratingValue': 3}
#
# [540 rows x 4 columns]

# %%
reviewdf = pd.read_json('sharetea')

# %%
s = lambda x: list(x.values())[0]

# %%
reviewdf['reviewRating'] = reviewdf['reviewRating'].apply(s)

# %%
# import copy
# 
# #df = copy.deepcopy(reviewdf)

# %% [markdown]
# ## IMPORT GOOGLE REVIEWS

# %% [markdown]
# #### todo: make place id google maps api modular through api call

# %%
import googlemaps
from datetime import datetime
import requests

# %%
gmapsapikey = json.load(open('gmapsapikey.json', 'r'))[0]

# %%
url = f'https://maps.googleapis.com/maps/api/place/details/json?key={gmapsapikey}&place_id=ChIJNc4K5cTCQIYRe9OyIN7DcGE&fields=name,review'
response = requests.get(url, headers=headers)

# %%
googlereviewdict = json.loads(response.content.decode('utf-8'))['result']['reviews']
googlereviewdict = {googlereviewdict.index(i):i for i in googlereviewdict}

googlereviewdf = pd.DataFrame(googlereviewdict).T

# %%
googlereviewdf = googlereviewdf[['author_name','rating','text']]
googlereviewdf.columns = ['author','reviewRating','description']
googlereviewdf
# Out:
#                        author reviewRating  \
# 0       Tristan & Ashley Boyd            5
# 1                   Pat Patel            4
# 2  Epiphany Animation Studios            3
# 3                       Na Li            4
# 4              Russell Monroe            2
#
#                                          description
# 0  Hubby found Mala Sichuan on Yelp and sent it a...
# 1  Very good traditional Chinese food. We definit...
# 2  It was alright. I think maybe they had an off ...
# 3  I come here once a while, it used to one of my...
# 4  This review is for the Finn Hall location, but...

# %%
reviewdf = pd.concat([reviewdf,googlereviewdf],sort = False)

# %%
reviewdf = reviewdf.reset_index().drop(['index'],axis=1)

# %%
#reviewdf['reviewRating'] = reviewdf['reviewRating'].apply(lambda x:x['ratingValue'])
reviewdf['description'] = reviewdf['description'].apply(lambda x:x.replace('\n','').replace('-',' ').lower())
reviewdf['description'] = reviewdf['description'].apply(lambda x:' '.join([i for i in x.split(" ") if len(i)>2]))
translator = str.maketrans(string.punctuation, ' '*len(string.punctuation)) #map punctuation to space
reviewdf['description'] = reviewdf['description'].apply(lambda x:x.translate(translator)).apply(lambda x: ' '.join(x.split()))

# %%
reviewdf.head()
# Out:
#      index      author datePublished  \
# 0        0      Tom P.    2019-08-10
# 1        1  Henry V L.    2019-08-20
# 10      10    Joiya A.    2019-03-17
# 100      0    Jason L.    2017-08-09
# 101      1   Melina H.    2018-12-30
#
#                                            description  reviewRating
# 0    visited sharetea chinatown for the first time ...             5
# 1    sharetea nooo thanks cuz boba lifeeee haha jk ...             3
# 10   finally made sharetea after having bookmarked ...             4
# 100  score 8 2 10 8 10 furniture ambience8 10 drink...             5
# 101  always quick service super patient with new cl...             5

# %% [markdown]
# # IMPORT USER REVIEWS

# %%
def grabfullreviws(ureviews):
    fullreviews = []
    curreview = ''
    for i in range(len(ureviews)):
        #print('\n')
        if not (i == len(ureviews)-1):
            if not type(ureviews[i]) == str:
                #print('not a review',ureviews[i],type(ureviews[i]))
                pass
            elif not type(ureviews[i+1]) == str:
                #print('middle of a review',ureviews[i],type(ureviews[i]))
                curreview = curreview + ureviews[i]
            elif type(ureviews[i+1]) == str:
                #print('end of a review',ureviews[i],type(ureviews[i]))
                curreview = curreview + ureviews[i]
                fullreviews.append(curreview)
                curreview = ''
        else:
            curreview = curreview + ureviews[i]
            fullreviews.append(curreview)
    return fullreviews

# %%
unextpage = 'something'
userpage = 'https://www.yelp.com/user_details_reviews_self?rec_pagestart=0&userid=2fKJeKlPi9le_ta7DPVW_A'
userreviewdf = pd.DataFrame()

upath_reviews = '//p[@lang="en"]//node()'
upath_nextpage = '//a[@class="u-decoration-none next pagination-links_anchor"]'
upath_starrating = '//div[@class="biz-rating__stars"]//div'

while len(unextpage) > 0:

    userpage = requests.get(userpage, headers = headers)#,proxies={"http": proxy, "https": proxy})
    
    uparser = html.fromstring(userpage.content)

    ureviews = uparser.xpath(upath_reviews)

    unextpage = uparser.xpath(upath_nextpage)
    
    if len(unextpage) > 0:
        print(unextpage)
        userpage = unextpage[0].get('href')
    ustarratingpath = uparser.xpath(upath_starrating)

    ureviews = [str(i) if not "Element br" in str(i) else 0 for i in ureviews ]

    ufullreviews = grabfullreviws(ureviews)

    fullstars = [i.get('title') for i in ustarratingpath]

    userreviewdf = pd.concat([userreviewdf,pd.DataFrame(list(zip(fullstars,fullreviews)))])
# Out:
# [<Element a at 0x11db28110>]
# [<Element a at 0x11d5d3ef0>]
# [<Element a at 0x132a5f650>]
# [<Element a at 0x11d532b90>]
# [<Element a at 0x132a72710>]

# %%
userreviewdf.columns = ['rating','description']

# %%
userreviewdf.head()
# Out:
#             rating                                        description
# 0  4.0 star rating  I'm writing this review because I noticed that...
# 1  5.0 star rating  TLDR: Over rated Mediterranean cuisine with de...
# 2  5.0 star rating  I came in here initially about to order a burg...
# 3  5.0 star rating  This HEB is legendary. Coming from Houston, I ...
# 4  5.0 star rating  I didn't expect the barbecue out of an HEB to ...

# %% [markdown]
# # GRAB MENU ITEMS

# %%
menuitems = json.load(open('teamenu.json'))
#menuitems = [x[3:].strip() for x in list(menuitems.keys())]
menitems = [x.lower() for x in menuitems]

# %% [markdown]
# # USER PREFERENCES

# %% [markdown]
# ## scrape wikipedia for chinese foods (only run once, save results as JSON)

# %%
from bs4 import BeautifulSoup

# %%
wikipage = 'https://en.wikipedia.org/wiki/List_of_Chinese_dishes'
wikipage = requests.get(wikipage).text
wikidf = pd.DataFrame()

soup = BeautifulSoup(wikipage)

my_tables = soup.findAll('table',{'class':'wikitable'})

# %%
chinesefoods = []
for table in my_tables:
    alla = list(table.findAll('a'))
    chinesefoods = chinesefoods +[x for x in[alla[i].get('title') for i in range(len(alla))] if type(x) == str]

# %%
from nltk.corpus import wordnet as wn
allfoods = list(set([w for s in wn.synset('food.n.02').closure(lambda s:s.hyponyms()) for w in s.lemma_names()])) + chinesefoods

# %%
len(allfoods)
# Out:
# 1721

# %% [markdown]
# ## food preferences by users reviews

# %%
search = lambda x: [food for food in allfoods if food in x]

userreviewdf['containedFood='] = userreviewdf['description'].apply(search)

# %% [markdown]
# ## RANKING MENU ITEMS

# %%
food = [x.lower() for x in food]

# %%
for i in menuitems:
    test = i.split(" ")
    test = [x.lower() for x in test]
    print(i)
    for j in test:
        if j in food:
            print ('y',j)
# Out:
# Top Notch Pot the Outlaws
# Sauerkraut Fish and Lamb Pot
# y fish
# y lamb
# Country Style Blood Curd Dish
# Devourable Beef Pot
# y beef
# and Crispy Chicken
# y chicken
# Duck Stew
# y duck
# Konjac Beef
# y beef
# Lotus Tofu
# Three Pepper Beaten Duck
# y pepper
# y duck
# Tea Smoked Duck
# y duck
# Four Joy Lion Head
# Fragrant Ribs
# Northern Boiling Fish
# y fish
# Sauerkraut Fish Pot
# y fish
# Chengdu Style Pot Roasted Tilapia
# Mala Pot Roasted Tilapia
# Bean Curd Tilapia Stew
# y bean
# Pot Roasted Black Bean Tilapia
# y bean
# Steamed Tilapia
# Sweet and Sour Crispy Tilapia
# Scallion Pot Roasted Tilapia
# y scallion
# Water Boiled Beef
# y beef
# Cumin Beef
# y beef
# Black Pepper Beef
# y pepper
# y beef
# Mala Beef Tofu
# y beef
# Mongolian Beef
# y beef
# Baby Pepper Black Bean Beef
# y pepper
# y bean
# y beef
# Baby Pepper and Shredded Beef
# y pepper
# y beef
# Satay Beef
# y beef
# Sauteed Lamb with Veggies
# y lamb
# Cumin Lamb
# y lamb

# %%
menitems
# Out:
# ['passionfruit juice with yakult',
#  'mango juice with yakult',
#  'classic milk tea',
#  'honey milk tea',
#  'ginger milk tea',
#  'okinawa pearl milk tea brown',
#  'hokkaido pearl milk tea',
#  'classic coffee',
#  'classic pearl milk tea',
#  'mango green milk tea',
#  'taro pearl milk tea',
#  'matcha red bean milk tea',
#  'qq happy family milk tea',
#  'ice cream black/green tea',
#  'coffee jelly milk tea',
#  'cocoa lover',
#  'black/green tea with fresh milk',
#  'oolong/high mountain tea with fresh milk',
#  'matcha with fresh milk',
#  'wintermelon with fresh milk',
#  'herb jelly with fresh milk',
#  'handmade taro fresh',
#  'classic black/green tea',
#  'oolong green tea',
#  'wintermelon tea',
#  'high mountain green tea',
#  'honey black/green tea']

# %%
import math

# %%
search = lambda x: [menitem for menitem in menitems if menitem[:math.floor(0.75*len(menitem))] in x]
reviewdf['containedMenuItems'] = reviewdf['description'].apply(search)

# %%
menitemstoreviews = {}
for menitem in menitems:
    menitemstoreviews[menitem] = [{},list(reviewdf[reviewdf['containedMenuItems'].map(lambda d: menitem in d)].index)]

# %%
test= copy.deepcopy(menitemstoreviews)

# %%
tot4plusreviews = len(reviewdf[reviewdf['reviewRating'] >= 4])

# %%
#total number of 4 plus reviews
for item in menitemstoreviews:
    #print(item,'------',end = '')
    allratings = []
    fourpluscounter = 0
    twominuscounter = 0
    totalrev = len(menitemstoreviews[item][1])
    
    for rev in menitemstoreviews[item][1]:
        curstar = reviewdf.iloc[rev]['reviewRating']
        allratings.append(curstar)
        if curstar >= 4:
            fourpluscounter += 1
        elif curstar <= 2:
            twominuscounter += 1
    if not totalrev == 0:
        menitemstoreviews[item][0]['extremerev'] = (fourpluscounter - twominuscounter) / (2 * totalrev)
    else:
        menitemstoreviews[item][0]['extremerev'] = 0
    menitemstoreviews[item][0]['percentageoftotalreviews'] = 10 * (fourpluscounter) / tot4plusreviews
        
    if not len(allratings) == 0:
        menitemstoreviews[item][0]['avgrev'] = sum(allratings)/(5 * len(allratings))
        #print('av rating',sum(allratings)/len(allratings))
    else:
        menitemstoreviews[item][0]['avgrev'] = 0
        #print('no reviews')

# %%
itemratings = pd.DataFrame(menitemstoreviews).T
itemratings.columns = ['ratings','indexes']

# %%
itemratings['totalscore'] = itemratings['ratings'].apply(lambda x: sum(x.values()))

# %%
itemratings['totalscore'].sort_values(ascending = False)
# Out:
# wintermelon tea                             1.623614
# okinawa pearl milk tea brown                1.563986
# wintermelon with fresh milk                 1.525381
# matcha with fresh milk                      1.525381
# honey milk tea                              1.511235
# taro pearl milk tea                         1.506236
# cocoa lover                                 1.410237
# classic milk tea                            1.392567
# mango juice with yakult                     1.325381
# high mountain green tea                     1.325381
# qq happy family milk tea                    1.325381
# matcha red bean milk tea                    1.325381
# mango green milk tea                        1.325236
# handmade taro fresh                         1.004714
# hokkaido pearl milk tea                     0.976142
# classic pearl milk tea                      0.925761
# ginger milk tea                             0.901523
# classic coffee                              0.000000
# honey black/green tea                       0.000000
# ice cream black/green tea                   0.000000
# coffee jelly milk tea                       0.000000
# black/green tea with fresh milk             0.000000
# oolong/high mountain tea with fresh milk    0.000000
# herb jelly with fresh milk                  0.000000
# classic black/green tea                     0.000000
# oolong green tea                            0.000000
# passionfruit juice with yakult              0.000000
# Name: totalscore, dtype: float64

# %%
itemratings.loc['wintermelon tea']['ratings']
# Out:
# {'extremerev': 0.34,
#  'percentageoftotalreviews': 0.5076142131979695,
#  'avgrev': 0.776}

# %%
reviewdf[reviewdf['description'].map(lambda d: 'okinawa pearl milk tea' in d)]
# Out:
#      index       author datePublished  \
# 127      7     Cindy S.    2016-04-04
# 152     12       Mai N.    2015-12-02
# 162      2     Vicky L.    2017-02-13
# 177     17     Vicky N.    2016-12-17
# 19      19       Fox E.    2019-02-27
# 212     12     Jerry C.    2016-03-04
# 223      3    Conrad L.    2015-12-05
# 241      1    Jeremy T.    2016-12-19
# 246      6       Jen D.    2017-01-29
# 248      8      Ngan H.    2015-10-12
# 286      6    Luther F.    2016-07-23
# 353     13    Angela C.    2016-02-15
# 41       1    Bailey I.    2019-06-18
# 417     17         M N.    2017-02-19
# 440      0    Teresa B.    2016-01-04
# 48       8  Fareedha P.    2018-01-16
# 76      16      Gina N.    2019-03-15
# 93      13     Raven G.    2018-05-24
# 96      16       Ken A.    2019-02-27
#
#                                            description  reviewRating  \
# 127  sharetea new favorite drink house chinatown th...             4
# 152  lot yelp reviews have been complaining about s...             4
# 162  service the slower end but nonetheless drink o...             3
# 177  the last time was here was year ago and they v...             5
# 19   i m gonna get fat cuz always shareteai wanna d...             5
# 212  nice employees chinatown the twilight zone nah...             4
# 223  update they now have p a system that you can h...             4
# 241  the milk teas here are easily some the best ho...             4
# 246  first review 2017 boba there are plethora boba...             4
# 248  new tapioca place from now on they made good d...             5
# 286  this the best bubble tea place houston hands d...             5
# 353  really yummy drinks heard lots good things abo...             4
# 41   idk what say except love this place soo much a...             5
# 417  the taro cereal slush earned them extra star t...             4
# 440  the best tea house htown hands down get the ok...             5
# 48   the okinawa pearl milk tea kiwi fruit tea with...             4
# 76   hands down favorite place come and get boba dr...             5
# 93   that okinawa pearl milk tea with roasted brown...             4
# 96   got the okinawa pearl milk tea and surprisingl...             4
#
#                                     containedMenuItems
# 127            [classic milk tea, taro pearl milk tea]
# 152                                                 []
# 162                                                 []
# 177                                                 []
# 19                            [classic pearl milk tea]
# 212                                                 []
# 223                                                 []
# 241                                                 []
# 246                                                 []
# 248                                                 []
# 286  [classic milk tea, honey milk tea, hokkaido pe...
# 353                                                 []
# 41                                                  []
# 417                                                 []
# 440                                                 []
# 48                                                  []
# 76                                                  []
# 93                                                  []
# 96                                                  []

# %%
reviewdf.iloc[548]['description']
# Out:
# 'one the better sichuan restaurants the greater houston area food 7service 5ambiance 5overall 6appetizers don remember the translations try best translate from chinese dan dan noodles executed well but nothing special garlic puree with pork slices overall unique take but too sweet and not spicy enough reference 888 version this spicy beef slices beef too tough spicy herb flavor doesn work for this dish entrees phoenix flavor chili chicken the best ever had america china this classic szechuan dish executed perfectly here with the perfect balance spiciness garlic and chicken mouth watering indeed water boiled fish quite good though tossup between this one and 888 version excellent with rice spicy enough mouth watering beef parents liked this dish but the beef was ordinary sauce similar the water boiled fish string beans with bamboo the meat sauce that goes with the beans superb proper amount wok hei this demanding dish bamboo tender food gets for the great entrees spoiled the very mediocre apps service ordinary that while they are reasonably polite they randomly forget certain orders and such service speed can quite slow during busy nights ambiance fairly ordinary but decent for chinese restaurant waiting area uncomfortable otherwise fairly clean scoring guidelines overall score average food service and ambiance rounding subjective based impression restaurant total food score average apps entrees and desserts places without apps dessert have the entree score instead counted multiple times denotes estimated score not included denotes noteworthy items 90th percentile denotes exceptional cuisine 98th percentile'

# %%
pd.DataFrame(menitemstoreviews).T
# Out:
#                                                                                    0  \
# top notch pot the outlaws          {'extremerev': 0, 'percentageoftotalreviews': ...
# sauerkraut fish and lamb pot       {'extremerev': 0, 'percentageoftotalreviews': ...
# country style blood curd dish      {'extremerev': 0.5, 'percentageoftotalreviews'...
# devourable beef pot                {'extremerev': 0.0, 'percentageoftotalreviews'...
# and crispy chicken                 {'extremerev': 0.3918918918918919, 'percentage...
# duck stew                          {'extremerev': 0.0, 'percentageoftotalreviews'...
# konjac beef                        {'extremerev': 0, 'percentageoftotalreviews': ...
# lotus tofu                         {'extremerev': 0.375, 'percentageoftotalreview...
# three pepper beaten duck           {'extremerev': 0.5, 'percentageoftotalreviews'...
# tea smoked duck                    {'extremerev': 0.3695652173913043, 'percentage...
# four joy lion head                 {'extremerev': 0.5, 'percentageoftotalreviews'...
# fragrant ribs                      {'extremerev': 0.375, 'percentageoftotalreview...
# northern boiling fish              {'extremerev': 0.5, 'percentageoftotalreviews'...
# sauerkraut fish pot                {'extremerev': 0.5, 'percentageoftotalreviews'...
# chengdu style pot roasted tilapia  {'extremerev': 0.5, 'percentageoftotalreviews'...
# mala pot roasted tilapia           {'extremerev': 0.5, 'percentageoftotalreviews'...
# bean curd tilapia stew             {'extremerev': 0, 'percentageoftotalreviews': ...
# pot roasted black bean tilapia     {'extremerev': 0, 'percentageoftotalreviews': ...
# steamed tilapia                    {'extremerev': 0.5, 'percentageoftotalreviews'...
# sweet and sour crispy tilapia      {'extremerev': 0.5, 'percentageoftotalreviews'...
# scallion pot roasted tilapia       {'extremerev': 0, 'percentageoftotalreviews': ...
# water boiled beef                  {'extremerev': 0.4230769230769231, 'percentage...
# cumin beef                         {'extremerev': 0.4076923076923077, 'percentage...
# black pepper beef                  {'extremerev': 0.5, 'percentageoftotalreviews'...
# mala beef tofu                     {'extremerev': 0.4, 'percentageoftotalreviews'...
# mongolian beef                     {'extremerev': 0.4666666666666667, 'percentage...
# baby pepper black bean beef        {'extremerev': 0.0, 'percentageoftotalreviews'...
# baby pepper and shredded beef      {'extremerev': 0.5, 'percentageoftotalreviews'...
# satay beef                         {'extremerev': 0.5, 'percentageoftotalreviews'...
# sauteed lamb with veggies          {'extremerev': 0, 'percentageoftotalreviews': ...
# cumin lamb                         {'extremerev': 0.4722222222222222, 'percentage...
#
#                                                                                    1
# top notch pot the outlaws                                                         []
# sauerkraut fish and lamb pot                                                      []
# country style blood curd dish                                             [416, 438]
# devourable beef pot                                                       [502, 714]
# and crispy chicken                 [11, 29, 38, 48, 66, 94, 101, 102, 104, 113, 1...
# duck stew                                                                 [162, 625]
# konjac beef                                                                       []
# lotus tofu                                                        [64, 88, 180, 318]
# three pepper beaten duck               [103, 349, 486, 539, 628, 653, 655, 671, 739]
# tea smoked duck                    [31, 42, 64, 113, 116, 172, 212, 227, 237, 257...
# four joy lion head                                                   [351, 554, 674]
# fragrant ribs                                                    [69, 109, 223, 312]
# northern boiling fish                                                     [257, 472]
# sauerkraut fish pot                                                            [118]
# chengdu style pot roasted tilapia                                              [640]
# mala pot roasted tilapia                           [12, 69, 131, 164, 222, 307, 500]
# bean curd tilapia stew                                                            []
# pot roasted black bean tilapia                                                    []
# steamed tilapia                                                      [166, 214, 733]
# sweet and sour crispy tilapia                                                  [217]
# scallion pot roasted tilapia                                                      []
# water boiled beef                  [29, 101, 131, 194, 207, 235, 277, 409, 462, 4...
# cumin beef                         [5, 18, 22, 42, 57, 78, 81, 94, 95, 98, 113, 1...
# black pepper beef                            [84, 164, 177, 323, 337, 359, 383, 554]
# mala beef tofu                                             [126, 217, 278, 350, 462]
# mongolian beef                     [13, 18, 75, 84, 183, 190, 234, 237, 253, 266,...
# baby pepper black bean beef                                               [222, 298]
# baby pepper and shredded beef                                                  [568]
# satay beef                                                                     [687]
# sauteed lamb with veggies                                                         []
# cumin lamb                         [16, 35, 79, 120, 131, 167, 180, 200, 230, 253...

# %%
reviewdf[reviewdf['author']=='Tristan & Ashley Boyd']
# Out:
#                     author datePublished  \
# 740  Tristan & Ashley Boyd           NaN
#
#                                            description reviewRating  \
# 740  hubby found mala sichuan on yelp and sent it a...            5
#
#        containedMenuItems
# 740  [and crispy chicken]

# %%
reviewdf.iloc[473]['description']
# Out:
# 'good prices, a ton of food and a friendly staff. the garlic bacon rolls with cucumbers and the red hot oil dumplings are good to start off with. the spicy crispy chicken was disappointing this time but the water boiled beef was good.'

# %%
#reviewdf.to_json('bigmala')
